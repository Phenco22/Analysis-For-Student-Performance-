# %%
# Importing the libary numpy and indicating it as np
import numpy as np

# %%
# importing library named pandas then representing it as pd
import pandas as pd

# %% [markdown]
#  ## SECTION A: BASIC EXPLORATION

# %%
'''loading the student performance.csv file into a DataFrame using read_csv,
then subset the DataFrame to include the first 10 Index or Row'''

student_performance = pd.read_csv("/StudentsPerformance.csv")
student_performance.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
# Selecting the last ten Rows from the student_performance DataFrame
student_performance.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
# Checking the overview of the dataset, in other to identify missing value
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# identifying the number of Rows and Columns
student_performance.shape
# Out:
# (1000, 8)

# %%
#Listing the variables names for each columns
Columns_List = student_performance.columns.tolist()
print("Column_Names:", Columns_List)
# Out:
# Column_Names: ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'math score', 'reading score', 'writing score']

# %%
'''There are different ways of identifying which column is categorical, and which column is numerial.
i will be showing you the two ways i know will be suitable to identify numerical and categorical columns'''

# IDENTIFYING THE NUMERICAL AND CATEGORICAL COLUMN USING .dtypes
# where ever you see Object it implies that the colum is categorical and wherever you see int, the column is numerical.

student_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# Listing out the column that are numerical, using the code below
numerical_columns= student_performance.select_dtypes(include=np.number).columns.tolist()
print("Numerical_Columns:", numerical_columns)
# Out:
# Numerical_Columns: ['math score', 'reading score', 'writing score']

# %%
# Listing out the column that are categorical, using the code below
categorical_column= student_performance.select_dtypes(include=object).columns.tolist()
print("Categorical_Column:", categorical_column)
# Out:
# Categorical_Column: ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %%
# Displaying the descriptive statistics for numerical columns
student_performance.describe(include=["number"])
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Displaying the descriptive statistics for numerical columns
student_performance.describe(exclude=["object"])
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# To check if there are any missing value in the data set
missing_by_column = student_performance.isna().sum()
missing_by_column
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ## SECTION B : FILTERING AND CONDITIONAL SELECTION

# %%
# selecting rows of students who completed the test preparation course
student_performance[student_performance["test preparation course"] == "completed"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# 13     male        group A                some college      standard
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Students who scored above 70 in math. i.e displaying the rows with score in math greater than 70.
student_performance[student_performance["math score"] > 70 ]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Female students who scored at least 65 in all three subjects
student_performance[(student_performance["gender"] == "female") & (student_performance["math score"] >= 65) &
 (student_performance["reading score"] >= 65) &
  (student_performance["writing score"] >= 65)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 989  female        group D                some college  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Number of Students Whose Lunch are Free/Reduced
lunch_count = student_performance["lunch"].value_counts()
student_free_reduced_lunch ="Number of Student free/reduced lunch:", lunch_count["free/reduced"]
student_free_reduced_lunch
# Out:
# ('Number of Student free/reduced lunch:', np.int64(355))

# %%
lunch_count = student_performance["lunch"].value_counts()
lunch_count
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %% [markdown]
# ## SECTION C: GROUPBY & AGGREGATION

# %%
# Grouping Student Average Math Scores By Gender
average_mathscores = student_performance.groupby('gender')['math score'].mean()
average_mathscores
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
# Grouping student average scores(math,reading,writing) by parental level of education
average_score_numerical = student_performance.groupby('parental level of education')[['math score','reading score','writing score']].mean()
average_score_numerical
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
## Comparing average scores of students with vs without test preparation (note:'none'refers to students who did notc omplete the test preparation course).
avg_scoreswith_withoutTP = student_performance.groupby('test preparation course')[['math score','reading score','writing score']].mean()
avg_scoreswith_withoutTP
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
#  Students with test preparation course have higher marks than the ones without, perhaps, the test preparation have significant impact on overall student performance.

# %% [markdown]
# ##SECTION D: VISUALIZATION

# %%
import matplotlib.pyplot as plt

# %%
# HISTOGRAM FOR MATH SCORE
plt.figure(figsize=(8, 5))
plt.hist(student_performance['math score'], bins=20, color= 'skyblue', edgecolor= 'black')
plt.xlabel('Math Score')
plt.ylabel('Frequency')
plt.title('Math Score Distribution')
plt.show()

# %%
# HISTOGRAM FOR READING SCORE
plt.hist(student_performance['reading score'], bins=20, color= 'yellow', edgecolor= 'black')
plt.xlabel('Reading Score')
plt.ylabel('Frequency')
plt.title('Reading Score Distribution')
plt.show()

# %%
# HISTOGRAM FOR WRITING SCORE
plt.hist(student_performance['writing score'], bins=20, color= 'red', edgecolor= 'black')
plt.xlabel('Writing Score')
plt.ylabel('Frequency')
plt.title('Writing Score Distribution')
plt.show()

# %%
# A bar plot showing average score by gender
avg_score_by_gender = student_performance.groupby('gender')[['math score', 'reading score', 'writing score']].mean()
print(avg_score_by_gender)
avg_score_by_gender.plot(kind='bar', figsize=(8, 5), edgecolor='black')
plt.xlabel('Gender')
plt.ylabel('Average Score')
plt.title('Average Score by Gender')
plt.show()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %% [markdown]
# ## SECTION E: INTERPRETATION

# %% [markdown]
# Does test preparation appear to improve performance?
#
# Students who completed the test preparation course achieved higher average scores in mathematics, reading, and writing than those who did not complete the course. This suggests that the test preparation program has a positive impact on academic performance. The improved scores indicate that students may benefit from the skills and strategies taught during the prep course. As a result, participation in the test preparation course appears to enhance overall student achievement. Therefore, the test preparation course appear to improve performance.
